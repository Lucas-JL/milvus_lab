# %%
from pymilvus import MilvusClient

# %%
# client = MilvusClient(
#     uri='http://localhost:19530',
#     user="root",
#     password="Milvus"
#     )

# %%
import time


client = MilvusClient(
    uri='http://127.0.0.1:19530',
    token="root:Milvus",
    timeout=1000,
    db_name="default"
)
